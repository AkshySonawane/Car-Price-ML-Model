# %%
import numpy as np
import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
df=pd.read_csv('car_price.csv')
df.head()
# Out:
#    symboling normalized_losses Fuel_type make num_of_doors   aspiration  \
# 0          3                 ?       gas  std          two  convertible
# 1          3                 ?       gas  std          two  convertible
# 2          1                 ?       gas  std          two    hatchback
# 3          2               164       gas  std         four        sedan
# 4          2               164       gas  std         four        sedan
#
#   wheel_base engine_location  drive_wheels   body_style  length  width  \
# 0        rwd           front          88.6  alfa-romero   168.8   64.1
# 1        rwd           front          88.6  alfa-romero   168.8   64.1
# 2        rwd           front          94.5  alfa-romero   171.2   65.5
# 3        fwd           front          99.8         audi   176.6   66.2
# 4        4wd           front          99.4         audi   176.6   66.4
#
#    height  curb_weight engine_type num_of_cylinders  engine_size fuel_system  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized_losses  205 non-null    object
#  2   Fuel_type          205 non-null    object
#  3   make               205 non-null    object
#  4   num_of_doors       205 non-null    object
#  5   aspiration         205 non-null    object
#  6   wheel_base         205 non-null    object
#  7   engine_location    205 non-null    object
#  8   drive_wheels       205 non-null    float64
#  9   body_style         205 non-null    object
#  10  length             205 non-null    float64
#  11  width              205 non-null    float64
#  12  height             205 non-null    float64
#  13  curb_weight        205 non-null    int64
#  14  engine_type        205 non-null    object
#  15  num_of_cylinders   205 non-null    object
# ...

# %%
df = df.replace({'?': np.nan})

# %%
df.isnull().sum()
# Out:
# symboling            0
# normalized_losses    0
# Fuel_type            0
# make                 0
# num_of_doors         0
# aspiration           0
# wheel_base           0
# engine_location      0
# drive_wheels         0
# body_style           0
# length               0
# width                0
# height               0
# curb_weight          0
# engine_type          0
# num_of_cylinders     0
# engine_size          0
# fuel_system          0
# bore                 0
# stroke               0
# compression_ratio    0
# horsepower           0
# peak_rpm             0
# city_mpg             0
# highway_mpg          0
# price                0
# dtype: int64

# %%
df.isnull().sum()[df.isnull().sum()> 0]
# Out:
# Series([], dtype: int64)

# %%
len(df.isnull().sum()[df.isnull().sum()> 0])
# Out:
# 7

# %%
df.normalized_losses = df.normalized_losses.astype('float')

# %%
df.normalized_losses = df.normalized_losses.fillna(df.normalized_losses.mean())

# %%
df.bore = df.bore.astype('float')

# %%
df.bore = df.bore.fillna(df.bore.mean())

# %%
df.stroke = df.stroke.astype('float')

# %%
df.stroke = df.stroke.fillna(df.stroke.mean())

# %%
df.horsepower = df.horsepower.astype('float')

# %%
df.horsepower = df.horsepower.fillna(df.horsepower.mean())

# %%
df.peak_rpm = df.peak_rpm.astype('float')

# %%
df.peak_rpm = df.peak_rpm.fillna(df.peak_rpm.mean())

# %%
# Replace 'two' and 'four' with numeric values
df['num_of_doors'].replace({'two': 2, 'four': 4}, inplace=True)

# Convert the 'num_of_doors' column to float
df['num_of_doors'] = df['num_of_doors'].astype('float')

df.num_of_doors = df.num_of_doors.astype('float')

# %%
df.num_of_doors = df.num_of_doors.fillna(df.num_of_doors.mean())

# %%
df.price = df.price.astype('float')

# %%
df.price = df.price.fillna(df.price.mean())

# %%
# Assuming df is your DataFrame
value_counts = df['num_of_doors'].value_counts()

# Display the value counts
print(value_counts)
# Out:
# num_of_doors
# 4.000000    114
# 2.000000     89
# 3.123153      2
# Name: count, dtype: int64

# %%
# Assuming df is your DataFrame
df = df.dropna()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized_losses  205 non-null    float64
#  2   Fuel_type          205 non-null    object
#  3   make               205 non-null    object
#  4   num_of_doors       205 non-null    float64
#  5   aspiration         205 non-null    object
#  6   wheel_base         205 non-null    object
#  7   engine_location    205 non-null    object
#  8   drive_wheels       205 non-null    float64
#  9   body_style         205 non-null    object
#  10  length             205 non-null    float64
#  11  width              205 non-null    float64
#  12  height             205 non-null    float64
#  13  curb_weight        205 non-null    int64
#  14  engine_type        205 non-null    object
#  15  num_of_cylinders   205 non-null    object
# ...

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

# %%
df[df.select_dtypes(include=['object']).columns] = df[df.select_dtypes(include=['object']).columns].apply(le.fit_transform)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized_losses  205 non-null    float64
#  2   Fuel_type          205 non-null    int32
#  3   make               205 non-null    int32
#  4   num_of_doors       205 non-null    float64
#  5   aspiration         205 non-null    int32
#  6   wheel_base         205 non-null    int32
#  7   engine_location    205 non-null    int32
#  8   drive_wheels       205 non-null    float64
#  9   body_style         205 non-null    int32
#  10  length             205 non-null    float64
#  11  width              205 non-null    float64
#  12  height             205 non-null    float64
#  13  curb_weight        205 non-null    int64
#  14  engine_type        205 non-null    int32
#  15  num_of_cylinders   205 non-null    int32
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
df = df1

# %%
df_train, df_test = train_test_split(df, test_size= .2)

# %%
df_train_y = df_train.iloc[:, -1]
df_test_y = df_test.iloc[:, -1]

# %%
df_train_x = df_train.iloc[:, :-1]
df_test_x = df_test.iloc[:, :-1]

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
#Building model on train data :)
lr.fit(df_train_x, df_train_y)
# Out:
# LinearRegression()

# %%
Rsqr = lr.score(df_train_x,df_train_y)
Rsqr
# Out:
# 0.8443785475611028

# %%
N = df_train_x.shape[0]
K = df_train_x.shape[1]

# %%
adj_Rsqr = 1-(1-Rsqr)*(N-1)/(N-K-1)
adj_Rsqr
# Out:
# 0.8116849651159563

# %%
lr.coef_
# Out:
# array([-1.28967215e+02,  1.60459980e+01,  8.66569279e+03, -3.91149871e+02,
#         2.30184587e+02, -4.73135651e+02, -5.88645963e+01,  2.27373675e-12,
#         1.10003263e+02, -1.77541157e+02, -1.66946103e+01,  8.37588111e+01,
#         1.68455604e+02,  4.12938762e+00,  8.26544372e+01, -2.29413227e+02,
#        -3.59096637e+01,  2.86730257e+02,  3.77615642e+02, -1.30289757e+03,
#         8.30735774e+02,  8.82582476e+01, -7.42334748e-01, -1.00448788e+02,
#         1.32735316e+02])

# %%
lr.intercept_
# Out:
# -36538.89028758164

# %%
pred_train = lr.predict(df_train_x)

# %%
pred_test = lr.predict(df_test_x)

# %%
pred_train
# Out:
# array([13815.41572641,  8899.72754773, 14428.88584895,  8700.64644218,
#        10712.81173173, 16463.64079213, 17073.96319015,  6195.54673629,
#        11889.70232891,  7205.70566717, 16467.85640783, 10095.14751399,
#        17950.22366745, 10242.03918599, 14337.45928752,  8334.80053694,
#        14240.81642092,  9184.72910805,  7380.48549084,  7167.98909787,
#        11899.58441827, 10718.71304276, 17314.76441629,  8074.64911691,
#        17157.87613237, 10036.1267551 ,  9954.17928602,  7712.85542867,
#         6957.94240999, 11471.87203104,  8051.17972612, 15357.57504768,
#         9029.8649397 ,  6761.97991462, 10903.24025459, 11301.09168289,
#         8614.06662972, 17618.74518843,  6702.85655269, 15348.44471207,
#         6530.69316353, 13623.89958945,  8664.31775816,  5725.62628283,
#         6898.24970607, 16128.90541974,  7016.49705984,  8717.54235054,
#         6135.87361767,  6646.09154896, 17903.02414807,  6088.83844184,
# ...

# %%
pred_test
# Out:
# array([17229.95572355, 16757.40866331, 16891.67579022,  9467.31818438,
#        16679.15779039, 13963.08595108,  5648.29294193, 12057.64542376,
#         9806.91411195, 12950.18101743,  7684.13409187, 16766.5624613 ,
#        16894.48144172, 16199.96632109,  8834.35832538,  9656.16774458,
#         8119.60468234, 11192.85550757, 12583.01875049,  9440.96137995,
#        17151.12628447,  5080.91361785,  9656.16774458,  9577.61074143,
#         9850.49336269,  6138.04604094, 12473.56929739, 15025.83834076,
#        30170.77105987, 11280.44474479,  7184.30606567,  7886.2697083 ,
#        16427.08264017,  6125.41166275, 18720.84719842,  9746.58268498,
#         6142.5204809 ])

# %%
err_test = df_test_y - pred_test

# %%
err_test
# Out:
# 102    -2830.955724
# 103    -3258.408663
# 179     -893.675790
# 123     -546.318184
# 199     2270.842210
# 196     2021.914049
# 30       830.707058
# 88     -2778.645424
# 193     2483.085888
# 83      1918.818983
# 158      213.865908
# 6        943.437539
# 104      304.518558
# 108    -2999.966321
# 142    -1059.358325
# 59      -811.167745
# 81       379.395318
# 191     2102.144492
# 82        45.981250
# 131      454.038620
# 13      3953.873716
# 150      267.086382
# 61       938.832255
# 79     -1888.610741
# 23     -1893.493363
# 162     3119.953959
# 170    -1274.569297
# 65      3254.161659
# 129   -16963.641707
# 56       564.555255
# 21     -1612.306066
# 90      -787.269708
# 116     1522.917360
# 156      812.588337
# 9      -5513.717845
# 42       598.417315
# 97      1856.479519
# Name: price, dtype: float64

# %%
err_train = df_train_y - pred_train
err_train
# Out:
# 66     4528.584274
# 38      195.272452
# 200    2416.114151
# 148    -687.646442
# 166   -1174.811732
# 12     4506.359208
# 101   -3574.963190
# 89     -696.546736
# 145    -630.702329
# 78     -536.705667
# 181    -717.856408
# 165    -797.147514
# 2     -1450.223667
# 188    -247.039186
# 172    3331.540712
# 186     160.199463
# 0      -745.816421
# 100     364.270892
# 22    -1003.485491
# 51    -1072.989098
# 167   -3450.584418
# 143    -758.713043
# 117     835.235584
# 185     120.350883
# 137    1462.123868
# 175     -48.126755
# 62      290.820714
# 35     -417.855429
# 77     -768.942410
# 169   -1482.872031
# 183     -76.179726
# 11     1567.424952
# 182   -1254.864940
# 92       87.020085
# 80     -944.240255
# 57     2343.908317
# 86     -425.066630
# 136     531.254812
# 160    1035.143447
# 4      2101.555288
# 138   -1412.693164
# 195    -208.899589
# 24    -2435.317758
# 152     762.373717
# 96      600.750294
# 110   -2268.905420
# 122     592.502940
# ...

# %%
mse_train = np.mean(np.square(err_train))
mse_train
# Out:
# 2543784.304319177

# %%
mse_test = np.mean(np.square(err_test))
mse_test
# Out:
# 11837474.046155084

# %%
rmse_train = np.sqrt(mse_train)
rmse_train
# Out:
# 1594.9245450237377

# %%
rmse_test = np.sqrt(mse_test)
rmse_test
# Out:
# 3440.5630420259827

# %%
mape_train = np.mean(np.abs(err_train*100)/(df_train_y))
mape_train
# Out:
# 11.655716611415652

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(err_train, '*')

# %%
plt.hist(err_train, bins=20, edgecolor='r')
# Out:
# (array([ 5.,  1.,  3.,  7., 12., 15., 22., 15., 21., 15.,  9.,  7.,  5.,
#          2.,  2.,  0.,  0.,  2.,  1.,  1.]),
#  array([-3574.96319015, -3108.92854309, -2642.89389603, -2176.85924897,
#         -1710.8246019 , -1244.78995484,  -778.75530778,  -312.72066072,
#           153.31398635,   619.34863341,  1085.38328047,  1551.41792753,
#          2017.4525746 ,  2483.48722166,  2949.52186872,  3415.55651579,
#          3881.59116285,  4347.62580991,  4813.66045697,  5279.69510404,
#          5745.7297511 ]),
#  <BarContainer object of 20 artists>)

# %%
pred_actual_df = pd.DataFrame()

# %%
pred_actual_df['Actual'] = df_train_y
pred_actual_df['Predicted'] = pred_train

# %%
pred_actual_df
# Out:
#            Actual     Predicted
# 66   18344.000000  13815.415726
# 38    9095.000000   8899.727548
# 200  16845.000000  14428.885849
# 148   8013.000000   8700.646442
# 166   9538.000000  10712.811732
# 12   20970.000000  16463.640792
# 101  13499.000000  17073.963190
# 89    5499.000000   6195.546736
# 145  11259.000000  11889.702329
# 78    6669.000000   7205.705667
# 181  15750.000000  16467.856408
# 165   9298.000000  10095.147514
# 2    16500.000000  17950.223667
# 188   9995.000000  10242.039186
# 172  17669.000000  14337.459288
# 186   8495.000000   8334.800537
# 0    13495.000000  14240.816421
# 100   9549.000000   9184.729108
# 22    6377.000000   7380.485491
# 51    6095.000000   7167.989098
# 167   8449.000000  11899.584418
# 143   9960.000000  10718.713043
# 117  18150.000000  17314.764416
# 185   8195.000000   8074.649117
# 137  18620.000000  17157.876132
# 175   9988.000000  10036.126755
# 62   10245.000000   9954.179286
# 35    7295.000000   7712.855429
# ...

# %%
import seaborn as sns

# %%
sns.jointplot(x='Actual', y='Predicted', data=pred_actual_df, kind='reg')
# Out:
# C:\Users\Ankush Sonawane\anaconda3\envs\py310\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Ankush Sonawane\anaconda3\envs\py310\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Ankush Sonawane\anaconda3\envs\py310\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
def remove_outliers(df, col, k):
    mean = df[col].mean()
    global df1
    sd = df[col].std()
    final_list = [x for x in df[col] if (x> mean - k*sd)]
    final_list = [x for x in final_list if (x< mean + k*sd)]
    df1 = df.loc[df[col].isin(final_list)]; print(df1.shape)
    print("No. of outliers=>  ", df.shape[0]-df1.shape[0])

# %%
remove_outliers(df, 'price', 2)
# Out:
# (182, 26)
# No. of outliers=>   9
